# %%
import pandas as pd

df = pd.read_csv("../data/processed/model_dataset.csv")

df["date"] = pd.to_datetime(df["date"])

#df.head()
#df.info()
#df["target"].value_counts()
#df.columns
print(df.columns.tolist())
# Out:
# ['date', 'home_team', 'away_team', 'home_score', 'away_score', 'tournament', 'city', 'country', 'neutral', 'result', 'target', 'points', 'goals_for', 'goals_against', 'form_points', 'form_goals_for', 'form_goals_against', 'home_elo', 'away_elo', 'form_points_diff', 'goal_diff_recent', 'elo_diff']
